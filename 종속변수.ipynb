# %%
import pandas as pd

정상_df = pd.read_csv('2018년_정상시평균속도_읍면동.csv')
혼잡_df = pd.read_csv('2018년_혼잡시평균속도_읍면동.csv')

# %%
정상_df.drop_duplicates(['시도명'])
# Out:
#        행정구역코드      시도명     시군구명  읍면동명 평일주말구분  정상시평균속도
# 0     1101053    서울특별시      종로구   사직동     평일    55.86
# 422   2101051    부산광역시       중구   중앙동     평일    49.22
# 620   2201054    대구광역시       중구   삼덕동     평일    46.40
# 759   2301052    인천광역시       중구   연안동     평일    48.08
# 903   2401051    광주광역시       동구   충장동     평일    40.45
# 998   2501053    대전광역시       동구    효동     평일    55.95
# 1077  2601051    울산광역시       중구   학성동     평일    43.64
# 1133  2901011  세종특별자치시      세종시  조치원읍     평일    54.61
# 1150  3101154      경기도  수원시 장안구   파장동     평일    65.08
# 1702  3201011      강원도      춘천시   신북읍     평일    73.05
# 1887  3302011     충청북도      충주시   주덕읍     평일    68.94
# 2040  3401111     충청남도  천안시 동남구   목천읍     평일    72.83
# 2247  3501160     전라북도  전주시 완산구  동서학동     평일    66.78
# 2487  3601051     전라남도      목포시  용당1동     평일    43.38
# 2760  3701111     경상북도   포항시 남구  구룡포읍     평일    74.63
# 3091  3803011     경상남도      진주시   문산읍     평일    79.11
# ...

# %%
정상_df2 = 정상_df[정상_df['시도명'] == '제주특별자치도']

# %%
정상_df2.describe()
# Out:
#              행정구역코드    정상시평균속도
# count  4.100000e+01  41.000000
# mean   3.901463e+06  54.517317
# std    4.965482e+02  10.367343
# min    3.901011e+06  34.060000
# 25%    3.901056e+06  46.680000
# 50%    3.901066e+06  54.570000
# 75%    3.902052e+06  64.210000
# max    3.902062e+06  68.990000

# %%
혼잡_df = pd.read_csv('2018년_혼잡시평균속도_읍면동.csv')

# %%
혼잡_df.drop_duplicates(['시도명'])
# Out:
#        행정구역코드      시도명     시군구명  읍면동명 평일주말구분  혼잡시평균속도
# 0     1101053    서울특별시      종로구   사직동     평일    24.84
# 424   2101051    부산광역시       중구   중앙동     평일    17.59
# 630   2201054    대구광역시       중구   삼덕동     평일    15.01
# 769   2301052    인천광역시       중구   연안동     평일    16.76
# 920   2401051    광주광역시       동구   충장동     평일    13.35
# 1015  2501053    대전광역시       동구    효동     평일    20.66
# 1094  2601051    울산광역시       중구   학성동     평일    17.11
# 1150  2901011  세종특별자치시      세종시  조치원읍     평일    23.37
# 1167  3101154      경기도  수원시 장안구   파장동     평일    26.92
# 1730  3201011      강원도      춘천시   신북읍     평일    32.14
# 1923  3302011     충청북도      충주시   주덕읍     평일    39.03
# 2076  3401111     충청남도  천안시 동남구   목천읍     평일    36.00
# 2283  3501160     전라북도  전주시 완산구  동서학동     평일    25.05
# 2524  3601051     전라남도      목포시  용당1동     평일    15.30
# 2821  3701111     경상북도   포항시 남구  구룡포읍     평일    43.31
# 3153  3803011     경상남도      진주시   문산읍     평일    45.78
# ...

# %%
혼잡_df2 = 혼잡_df[혼잡_df['시도명'] == '제주특별자치도']

# %%
혼잡_df2.describe()
# Out:
#              행정구역코드    혼잡시평균속도
# count  4.300000e+01  41.000000
# mean   3.901443e+06  28.441220
# std    4.932021e+02  10.615021
# min    3.901011e+06  15.510000
# 25%    3.901054e+06  19.430000
# 50%    3.901065e+06  24.950000
# 75%    3.902052e+06  36.750000
# max    3.902062e+06  48.150000

# %%
train_df = pd.read_csv('train.csv')

# %%
train_df['target'].max()
# Out:
# 113.0

# %%
train_df['target'].min()
# Out:
# 1.0

# %%
train_df['target'].mean()
# Out:
# 42.78844180134633
